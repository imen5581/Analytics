# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Denis\Desktop\Скрипты\Анализ данных\Задание_1\PlayerPersonalData.csv')
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0           0             0   20801  Cristiano Ronaldo   32
# 1           1             1  158023           L. Messi   30
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
#
#                                   Flag  Overall  Potential            Club  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94  Real Madrid CF
# 1  https://cdn.sofifa.org/flags/52.png       93         93    FC Barcelona
#
#                                     Club Logo   Value   Wage  Special
# 0  https://cdn.sofifa.org/24/18/teams/243.png  €95.5M  €565K     2228
# 1  https://cdn.sofifa.org/24/18/teams/241.png   €105M  €565K     2154

# %%
# %matplotlib inline
ax = df.Age.plot.hist()
ax.set_title('Visualization')
ax.set_xlabel('ВОзраст')
ax.set_ylabel('Количество футболистов')
# Out:
# Text(0, 0.5, 'Количество футболистов')

# %%
sns.regplot(x=df["Age"], y=df["Wage"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d5229a04b5af> in <module>
# ----> 1 import seaborn as sns
#       2 sns.regplot(x=df["Age"], y=df["Wage"])
#
# ModuleNotFoundError: No module named 'seaborn'
